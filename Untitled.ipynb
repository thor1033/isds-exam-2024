# %%
import pandas as pd

# %%
# Basic statistical summary
output_file = 'data/merged_dst_data.csv'
df = pd.read_csv(output_file)
df.describe()
# Out:
#               year  cleaned_fuldtidsledige  cleaned_indbyggertal  average_age  \
# count  1000.000000              980.000000            980.000000   990.000000
# mean   2018.500000             1104.744898          56789.970408    43.322424
# std       2.873719             1902.095813          70262.606443     2.926463
# min    2014.000000               34.000000             78.000000    35.900000
# 25%    2016.000000              480.250000          29668.000000    41.400000
# 50%    2018.500000              712.500000          42866.000000    43.000000
# 75%    2021.000000             1071.500000          59216.000000    44.700000
# max    2023.000000            20800.000000         653664.000000    54.800000
#
#          cleaned_job  municipal_tax  cleaned_befolkning_og_indvandre  \
# count     990.000000     980.000000                       990.000000
# mean    31893.274747      25.296755                     34478.866667
# ...

# %%
# Group by municipality and calculate mean values for each
numeric_df = df.drop(columns=['municipality'])
yearly_summary = numeric_df.groupby('year').mean()
yearly_summary
# Out:
#       cleaned_fuldtidsledige  cleaned_indbyggertal  average_age   cleaned_job  \
# year
# 2014             1350.520408          55320.673469    42.436364  29989.585859
# 2015             1241.438776          55631.734694    42.656566  30199.454545
# 2016             1138.908163          56091.173469    42.848485  30650.515152
# 2017             1174.561224          56498.285714    43.017172  31191.252525
# 2018             1091.234694          56812.571429    43.196970  31704.929293
# 2019             1050.316327          57048.663265    43.395960  32205.979798
# 2020             1329.877551          57200.897959    43.659596  32453.979798
# 2021             1069.428571          57352.632653    43.885859  32124.161616
# 2022              761.091837          57676.918367    44.031313  33873.909091
# 2023              840.071429          58266.153061    44.095960  34538.979798
#
#       municipal_tax  cleaned_befolkning_og_indvandre  cleaned_uddannelse  \
# year
# ...

# %%
# Correlation matrix
# Drop non-numeric columns before calculating correlation
numeric_df = df.drop(columns=['municipality', 'year'])

# Now calculate the correlation matrix
correlation_matrix = numeric_df.corr()
correlation_matrix
# Out:
#                                       cleaned_fuldtidsledige  \
# cleaned_fuldtidsledige                              1.000000
# cleaned_indbyggertal                                0.947994
# average_age                                        -0.441515
# cleaned_job                                         0.964061
# municipal_tax                                      -0.218022
# cleaned_befolkning_og_indvandre                     0.966125
# cleaned_uddannelse                                  0.947238
# jobs_normalized                                     0.178731
# unemployed_normalized                               0.351324
# population_and_immigrants_normalized                0.118936
# education_normalized                               -0.091723
#
#                                       cleaned_indbyggertal  average_age  \
# cleaned_fuldtidsledige                            0.947994    -0.441515
# cleaned_indbyggertal                              1.000000    -0.457446
# ...

# %%
import matplotlib.pyplot as plt

# Plot histograms for all numerical columns
df.hist(bins=20, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
# Boxplot for each variable
df.plot(kind='box', subplots=True, layout=(4, 4), figsize=(15, 10), sharex=False, sharey=False)
plt.tight_layout()
plt.show()

# %%
# Line plot for yearly trends
plt.figure(figsize=(10, 6))
for column in ['jobs_normalized', 'unemployed_normalized', 'education_normalized']:
    plt.plot(yearly_summary.index, yearly_summary[column], label=column)
plt.legend()
plt.xlabel('Year')
plt.ylabel('Value')
plt.title('Yearly Trends')
plt.show()

# %%
3
